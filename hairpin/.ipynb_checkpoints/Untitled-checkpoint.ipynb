# %%
from pylab import *
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # $\beta$ hairping

# %%
path="/run/media/k1762355/Untitled/for-exam/research-project-assignment/umbrella-sampling-data/hairpin1_pulling_umbrella/bootstrap/"
#path="../for-exam/research-project-assignment/umbrella-sampling-data/hairpin1_pulling_umbrella/"

# %% [markdown]
# ### PMF

# %%
p=pd.read_table(path+"bootstrap_5/pmf.xvg",header=11,names=["z","E"])
figure(figsize=(4,3))
plot(p.z,p.E,".")
xlabel("reaction coordinate")
ylabel("pmf (kcal/mol)")

# %%
p=pd.read_table(path+"bootstrap_50/bsResult.xvg",header=12,names=["z","E","dE"])
figure(figsize=(4,3))
plot(p.z,p.E,"m",lw=0.8)
fill_between(p.z,p.E-p.dE,p.E+p.dE,color="gray",alpha=0.5)
xlabel("reaction coordinate (nm)",fontsize=13)
ylabel("pmf (kcal/mol)",fontsize=13)
tight_layout()
savefig("pmf.pdf")

# %% [markdown]
# ### comparing bootstraps

# %%
bootstrap=[5,20,50,70,100]
sigma=[]
for bstr in bootstrap:
    p=pd.read_table(path+"bootstrap_"+str(bstr)+"/bsResult.xvg",header=12,names=["z","E","dE"])
    sigma+=[p.dE]
sigma=transpose(sigma)

# %%
figure(figsize=(4,3))
plot(p.z,sigma,"-")
legend(bootstrap,ncol=3,fontsize=11)
xlabel("reaction coordinate (nm)",fontsize=13)
ylabel("pmf error est. (kcal/mol)",fontsize=13)
tight_layout()
#savefig("bootstrap_beta.pdf")

# %%
p=pd.read_table(path+"bootstrap_"+str(bstr)+"/bsProfs.xvg",header=11,names=["z","E"])
shape(p)
# Out:
# (14070, 2)

# %% [markdown]
# ### histograms
# follow Matlab code instead

# %%
df=pd.read_csv(path+"bootstrap_"+str(50)+'/all_hist.dat',sep=' ',header=None,skip_blank_lines=False)
events=np.split(df, df[df.isnull().all(1)].index)
bins=[events[i][0] for i in arange(len(events))]
h=array([array(events[i][1])  for i in arange(len(events))])/sum(events[0][1])# divide to obtain the frequency
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-44c5d4e83694> in <module>()
#       1
# ----> 2 df=pd.read_csv(path+"bootstrap_"+str(50)+'/all_hist.dat',sep=' ',header=None,skip_blank_lines=False)
#       3 events=np.split(df, df[df.isnull().all(1)].index)
#       4 bins=[events[i][0] for i in arange(len(events))]
#       5 h=array([array(events[i][1])  for i in arange(len(events))])/sum(events[0][1])# divide to obtain the frequency
#
# ~/miniconda3/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/miniconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/miniconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/miniconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'../for-exam/research-project-assignment/umbrella-sampling-data/hairpin1_pulling_umbrella/bootstrap_50/all_hist.dat' does not exist

# %%
figure(figsize=(4,3))
for i in arange(len(events)):
    plot(bins[i],h[i],lw=0.8,alpha=0.8)
xlabel("reaction coordinate (nm)")
ylabel("Frequency")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-efec567fb5c1> in <module>()
#       2 figure(figsize=(4,3))
#       3 for i in arange(len(events)):
# ----> 4     plot(bins[i],h[i],lw=0.8,alpha=0.8)
#       5 xlabel("reaction coordinate (nm)")
#       6 ylabel("Frequency")
#
# NameError: name 'bins' is not defined

# %%
p=pd.read_table(path+"/1-struct/pullf-umbrella.xvg",header=11,names=["t","F"])
plot(p.t,p.F)

# %%
p=pd.read_table(path+"/umbrella-location.dat",names=["R"],header=None)
R=array(p.R)
plot(R,"o")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3a3f704cf8ea> in <module>()
# ----> 1 p=pd.read_table(path+"/umbrella-location.dat",names=["R"],header=None)
#       2 R=array(p.R)
#       3 plot(R,"o")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'/run/media/k1762355/Untitled/for-exam/research-project-assignment/umbrella-sampling-data/hairpin1_pulling_umbrella/bootstrap//umbrella-location.dat' does not exist

# %% [markdown]
# ### H bond
# bond distance

# %%
data=[]
df=pd.read_csv(path+'/multiplot.dat',sep=' ',header=None,skip_blank_lines=False,names=["n","r"])
events=np.split(df, df[df.isnull().all(1)].index)
events=events[:-1]

for el in events:# it stores the first empty line, so we remove it
    data+=[el.dropna()]

# %%
figure(figsize=(4,3))
for d in data:
    plot(d.n,d.r,":",marker="o",ms=6,mfc="white",mew=2)
ylim(1.5,5)
xlim(-1,10)
xlabel("simulation number")
ylabel("bond distance ($\AA$)")
legend(arange(1,7),numpoints=1,ncol=1,loc="lower right")
tight_layout()
savefig("hairpin-HB2.pdf")

# %%
data=[]
df=pd.read_csv(path+'/TRP.dat',sep=' ',header=None,skip_blank_lines=False,names=["n","r"])
events=np.split(df, df[df.isnull().all(1)].index)
events=events[:-1]

for el in events:# it stores the first empty line, so we remove it
    data+=[el.dropna()]

# %%
figure(figsize=(4,3))
for d in data:
    plot(d.n,d.r,":",marker="o",ms=6,mfc="white",mew=2)
xlabel("simulation number")
ylabel("bond distance ($\AA$)")
tight_layout()
legend(["TRP4-TRP9", "TRP11-TRP2"],numpoints=1)
savefig("hairpin-TRP.pdf")

# %%
df.dropna()
# Out:
#         0          1
# 0     0.0   2.203841
# 1     1.0   4.778401
# 2     2.0   5.604624
# 3     3.0   7.417555
# 4     4.0   9.685117
# 5     5.0  11.674958
# 6     6.0  13.745669
# 7     7.0  15.967454
# 8     8.0  17.993917
# 9     9.0  19.956774
# 10   10.0  22.625427
# 11   11.0  23.766323
# 12   12.0  25.413204
# 13   13.0  27.414297
# 14   14.0  30.379515
# 15   15.0  31.100126
# 16   16.0  33.887684
# 17   17.0  36.110554
# 18   18.0  37.419930
# 19   19.0  39.126286
# 20   20.0  39.348194
# 22    0.0   1.989447
# 23    1.0   2.091765
# 24    2.0   1.889185
# 25    3.0   2.173705
# 26    4.0   3.488987
# 27    5.0   5.340618
# 28    6.0   6.563365
# 29    7.0   6.573696
# 30    8.0   9.531965
# ..    ...        ...
# 78   12.0   5.609227
# 79   13.0   5.941119
# 80   14.0   9.021026
# 81   15.0   8.827758
# 82   16.0  12.731338
# 83   17.0  13.139060
# 84   18.0  13.456085
# 85   19.0  13.767367
# 86   20.0  14.055167
# 88    0.0   2.285384
# 89    1.0   1.909606
# 90    2.0   2.473782
# 91    3.0   1.886244
# 92    4.0   1.789446
# 93    5.0   1.747142
# 94    6.0   2.122687
# 95    7.0   2.225845
# 96    8.0   2.030494
# 97    9.0   1.798142
# 98   10.0   3.237175
# 99   11.0   4.108393
# 100  12.0   3.487953
# 101  13.0   4.224030
# 102  14.0   5.363040
# 103  15.0   6.300573
# 104  16.0   8.868352
# 105  17.0   8.792500
# 106  18.0   8.480001
# 107  19.0   9.137018
# 108  20.0   9.324913
#
# [105 rows x 2 columns]

# %%
pd.read_csv?
