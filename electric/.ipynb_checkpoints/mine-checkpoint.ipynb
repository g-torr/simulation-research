# %%
from pylab import *

from glob import glob
from os.path import splitext,join
from glob import glob
from matplotlib.cm import *
# %matplotlib inline

# %%
data = {'0.1':[None],'-0.1':[None],
        '1.0':[None,None,None],'-1.0':[None,None,None],
        '0.2':[None,None,None,None,None,None],'-0.2':[None,None,None,None,None,None]}

plus100,minus100 = [],[]
plus200,minus200 = [],[]
plus1000,minus1000 = [],[]
allmV = []

for i,file_path in enumerate(glob('./md-electric-field-data/*/*/*q.out')):
    data = genfromtxt(file_path,dtype=float)
    
    x,y,z,w = data.T
    
    if i < 6 :
        y /= 0.2
        z /= 0.2
        w /= 0.2
        
        data = array([x,y,z,w]).T
        plus200 += [data]

    elif i < 12 :
        y /= 0.2
        z /= 0.2
        w /= 0.2

        data = array([x,y,z,w]).T
        minus200 += [data]
    elif i == 12 :
        y /= 0.1
        z /= 0.1
        w /= 0.1
        
        data = array([x,y,z,w]).T
        minus100 += [data]
    elif i == 13 :
        y /= 0.1
        z /= 0.1
        w /= 0.1

        data = array([x,y,z,w]).T
        plus100 += [data]
    elif i < 17 :
        plus1000 += [data]
    else :
        y /= 1.0
        z /= 1.0
        w /= 1.0

        minus1000 += [data]
        
    allmV += [data]
    
#     _,_,_,param,traj = file_path.split('/')
#     i = int(splitext(traj)[0][0])-1
    
#     if param[:param.index('-')] == 'plus': v = float(param[param.index('-')+1:-2])/1000
#     else : v = -float(param[param.index('-')+1:-2])/1000
  
    
#     data[str(v)][i] = frame,current,voltage,x

# %%
#figure(figsize=(4,3))
label = [ '-1000mV','-200mV','-100mV','100mV','200mV','1000mV' ]
norm = [-1.0,-0.2,-0.1,0.1,0.2,1.0]
nline  = 3*[None]
pline  = 3*[None]

for j,datum in enumerate([minus1000,minus200,minus100]):
    i = j/6.0; i = 1-i

    x,_,_,y = mean(array(datum),axis=0).T
    _,_,_,dy = std(array(datum),axis=0).T
    
    #slope, intercept, r_value, p_value, std_err = linregress(x,y)
    slope, _, _, _ = np.linalg.lstsq(x[:,np.newaxis], y)
    slope = slope[0]
    
    nline[j], = plot(x/1000,x*slope,"--",lw=2,color=winter(i),label='V = '+label[j])

    #plot(x,y,color=winter(i))
    fill_between(x/1000,y1=y+dy, y2=y-dy,alpha=0.4,color=winter(i))
    
for j,datum in enumerate([plus100,plus200,plus1000]):
    i = j/6.0; i = 1-i

    x,_,y,_ = mean(array(datum),axis=0).T
    _,_,dy,_ = std(array(datum),axis=0).T
    
    #slope, intercept, r_value, p_value, std_err = linregress(x,y)
    slope, _, _, _ = np.linalg.lstsq(x[:,np.newaxis], y)
    slope = slope[0]
    
    pline[j], = plot(x/1000,x*slope,"--",lw=2,color=copper(i),label='V = '+label[j])

    #plot(x,y,color=winter(i))
    fill_between(x/1000,y1=y+dy, y2=y-dy,alpha=0.4,color=copper(i))

tight_layout()

box = gca().get_position()

#gca().set_position([box.x0, box.y0, box.width, box.height*0.6])
legend1 = legend(handles=nline,fontsize=10,loc=(0.01,0.35),frameon=False)
legend1.set_title('Anions',prop={'size':12})
gca().add_artist(legend1)

legend2 = legend(handles=pline,fontsize=10,loc='lower left',frameon=False)
legend2.set_title('Cations',prop={'size':12})
gca().add_artist(legend2)


#axes[2].legend(array(roi3)+1,fontsize=14,loc='center left', bbox_to_anchor=(1, 0.5))
    
gca().ticklabel_format(style"sci")    
xlabel(r'Time, $t$ ($\mathrm{ns}$)',fontsize=12)
ylabel(r'Transl. Charge per Volt ($\mathrm{pC}/ \mathrm{V})$',fontsize=12);
#ylim(-8e-5,2e-5);
#savefig("going_opposite.pdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c9af2747ee09> in <module>()
#      51 #axes[2].legend(array(roi3)+1,fontsize=14,loc='center left', bbox_to_anchor=(1, 0.5))
#      52
# ---> 53 gca().ticklabel_format("sci")
#      54 xlabel(r'Time, $t$ ($\mathrm{ns}$)',fontsize=12)
#      55 ylabel(r'Transl. Charge per Volt ($\mathrm{pC}/ \mathrm{V})$',fontsize=12);
#
# TypeError: ticklabel_format() takes 1 positional argument but 2 were given

# %%
#figure(figsize=(4,3))
label = [ '-1000mV','-200mV','-100mV','100mV','200mV','1000mV' ]
norm = [-1.0,-0.2,-0.1,0.1,0.2,1.0]
nline  = 3*[None]
pline  = 3*[None]

for j,datum in enumerate([plus100,plus200,plus1000]):
    i = j/6.0; i = 1-i

    x,_,_,y = mean(array(datum),axis=0).T
    _,_,_,dy = std(array(datum),axis=0).T
    
    #slope, intercept, r_value, p_value, std_err = linregress(x,y)
    slope, _, _, _ = np.linalg.lstsq(x[:,np.newaxis], y)
    slope = slope[0]
    
    nline[j], = plot(x/1000,x*slope,"--",lw=2,color=winter(i),label='V = '+label[j])

    #plot(x,y,color=winter(i))
    fill_between(x/1000,y1=y+dy, y2=y-dy,alpha=0.4,color=winter(i))
    
for j,datum in enumerate([minus1000,minus200,minus100]):
    i = j/6.0; i = 1-i

    x,_,y,_ = mean(array(datum),axis=0).T
    _,_,dy,_ = std(array(datum),axis=0).T
    
    #slope, intercept, r_value, p_value, std_err = linregress(x,y)
    slope, _, _, _ = np.linalg.lstsq(x[:,np.newaxis], y)
    slope = slope[0]
    
    pline[j], = plot(x/1000,x*slope,"--",lw=2,color=copper(i),label='V = '+label[j])

    #plot(x,y,color=winter(i))
    fill_between(x/1000,y1=y+dy, y2=y-dy,alpha=0.4,color=copper(i))

#tight_layout()

box = gca().get_position()


legend1 = legend(handles=nline,fontsize=10,loc=(0.01,0.35),frameon=False)
legend1.set_title('Anions',prop={'size':12})
gca().add_artist(legend1)

legend2 = legend(handles=pline,fontsize=10,loc='upper left',frameon=False)
legend2.set_title('Cations',prop={'size':12})
gca().add_artist(legend2)


#axes[2].legend(array(roi3)+1,fontsize=14,loc='center left', bbox_to_anchor=(1, 0.5))
    
    
xlabel(r'Time, $t$ ($\mathrm{ns}$)',fontsize=12)
ylabel(r'Transl. Charge per Volt ($\mathrm{pC}/ \mathrm{V})$',fontsize=12);
#ylim(-8e-5,2e-5);
savefig("going_forward.pdf")

# %%
for j,datum in enumerate([minus1000,minus200,minus100]):
    print(j)
# Out:
# 0
# 1
# 2
